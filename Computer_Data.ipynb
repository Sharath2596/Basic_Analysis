# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
comp=pd.read_csv("Computer_Data.csv")

# %%
comp
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 0              1   1499     25    80    4      14   no    no     yes   94
# 1              2   1795     33    85    2      14   no    no     yes   94
# 2              3   1595     25   170    4      15   no    no     yes   94
# 3              4   1849     25   170    8      14   no    no      no   94
# 4              5   3295     33   340   16      14   no    no     yes   94
# ...          ...    ...    ...   ...  ...     ...  ...   ...     ...  ...
# 6254        6255   1690    100   528    8      15   no    no     yes   39
# 6255        6256   2223     66   850   16      15  yes   yes     yes   39
# 6256        6257   2654    100  1200   24      15  yes    no     yes   39
# 6257        6258   2195    100   850   16      15  yes    no     yes   39
# 6258        6259   2490    100   850   16      17  yes    no     yes   39
#
#       trend
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
comp.dtypes
# Out:
# Unnamed: 0     int64
# price          int64
# speed          int64
# hd             int64
# ram            int64
# screen         int64
# cd            object
# multi         object
# premium       object
# ads            int64
# trend          int64
# dtype: object

# %%
comp.size
# Out:
# 68849

# %%
comp.shape
# Out:
# (6259, 11)

# %%
comp.ndim
# Out:
# 2

# %%
comp.axes
# Out:
# [RangeIndex(start=0, stop=6259, step=1),
#  Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#         'premium', 'ads', 'trend'],
#        dtype='object')]

# %%
comp.columns
# Out:
# Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#        'premium', 'ads', 'trend'],
#       dtype='object')

# %%
comp.values
# Out:
# array([[1, 1499, 25, ..., 'yes', 94, 1],
#        [2, 1795, 33, ..., 'yes', 94, 1],
#        [3, 1595, 25, ..., 'yes', 94, 1],
#        ...,
#        [6257, 2654, 100, ..., 'yes', 39, 35],
#        [6258, 2195, 100, ..., 'yes', 39, 35],
#        [6259, 2490, 100, ..., 'yes', 39, 35]], dtype=object)

# %%
comp.describe()
# Out:
#         Unnamed: 0        price        speed           hd          ram  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   3130.000000  2219.576610    52.011024   416.601694     8.286947
# std    1806.961999   580.803956    21.157735   258.548445     5.631099
# min       1.000000   949.000000    25.000000    80.000000     2.000000
# 25%    1565.500000  1794.000000    33.000000   214.000000     4.000000
# 50%    3130.000000  2144.000000    50.000000   340.000000     8.000000
# 75%    4694.500000  2595.000000    66.000000   528.000000     8.000000
# max    6259.000000  5399.000000   100.000000  2100.000000    32.000000
#
#             screen          ads        trend
# count  6259.000000  6259.000000  6259.000000
# mean     14.608723   221.301007    15.926985
# std       0.905115    74.835284     7.873984
# min      14.000000    39.000000     1.000000
# 25%      14.000000   162.500000    10.000000
# 50%      14.000000   246.000000    16.000000
# ...

# %%
comp.head()
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0           1   1499     25   80    4      14  no    no     yes   94      1
# 1           2   1795     33   85    2      14  no    no     yes   94      1
# 2           3   1595     25  170    4      15  no    no     yes   94      1
# 3           4   1849     25  170    8      14  no    no      no   94      1
# 4           5   3295     33  340   16      14  no    no     yes   94      1

# %%
comp.tail()
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 6254        6255   1690    100   528    8      15   no    no     yes   39
# 6255        6256   2223     66   850   16      15  yes   yes     yes   39
# 6256        6257   2654    100  1200   24      15  yes    no     yes   39
# 6257        6258   2195    100   850   16      15  yes    no     yes   39
# 6258        6259   2490    100   850   16      17  yes    no     yes   39
#
#       trend
# 6254     35
# 6255     35
# 6256     35
# 6257     35
# 6258     35

# %%
comp['price']
# Out:
# 0       1499
# 1       1795
# 2       1595
# 3       1849
# 4       3295
#         ...
# 6254    1690
# 6255    2223
# 6256    2654
# 6257    2195
# 6258    2490
# Name: price, Length: 6259, dtype: int64

# %%
comp[['price']]
# Out:
#       price
# 0      1499
# 1      1795
# 2      1595
# 3      1849
# 4      3295
# ...     ...
# 6254   1690
# 6255   2223
# 6256   2654
# 6257   2195
# 6258   2490
#
# [6259 rows x 1 columns]

# %%
plt.hist(comp['price'])
# Out:
# (array([ 237., 1554., 1803., 1459.,  850.,  238.,   92.,   18.,    3.,
#            5.]),
#  array([ 949., 1394., 1839., 2284., 2729., 3174., 3619., 4064., 4509.,
#         4954., 5399.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(comp['price'],facecolor="pink",edgecolor="blue",bins=5)
# Out:
# (array([1791., 3262., 1088.,  110.,    8.]),
#  array([ 949., 1839., 2729., 3619., 4509., 5399.]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(comp['price'],facecolor="pink",edgecolor="blue",bins=5)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
plt.boxplot(comp["price"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
pd.crosstab(comp.price,comp.speed)
# Out:
# speed  25   33   50   66   75   100
# price
# 949      0    1    0    0    0    0
# 999      0    4    0    0    0    0
# 1049     0    2    0    0    0    0
# 1088     0    1    0    0    0    0
# 1099     0    2    0    0    0    0
# ...    ...  ...  ...  ...  ...  ...
# 4594     0    0    1    0    0    0
# 4694     0    0    0    1    0    0
# 4799     0    0    0    1    0    0
# 4999     0    0    0    2    0    0
# 5399     0    0    0    3    0    0
#
# [808 rows x 6 columns]

# %%
pd.crosstab(comp.price,comp.speed).plot(kind="bar")

# %%
comp.price.value_counts().plot(kind="pie")

# %%
plt.hist(comp["speed"])
# Out:
# (array([ 566., 2033.,    0.,  994.,    0., 2028.,  122.,    0.,    0.,
#          516.]),
#  array([ 25. ,  32.5,  40. ,  47.5,  55. ,  62.5,  70. ,  77.5,  85. ,
#          92.5, 100. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(comp["speed"],facecolor="red",edgecolor="blue",bins=5)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
plt.boxplot(comp["speed"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x275b6bb2cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x275b6bb2790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x275b6bb29a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x275b6bb9af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x275b6bb9e20>],
#  'means': []}

# %%
plt.boxplot(comp["speed"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
comp["speed"].value_counts()
# Out:
# 33     2033
# 66     2028
# 50      994
# 25      566
# 100     516
# 75      122
# Name: speed, dtype: int64

# %%
comp.speed.value_counts().plot(kind="pie")

# %%
plt.hist(comp["hd"],facecolor="red",edgecolor="blue",bins=4)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
plt.boxplot(comp["hd"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
comp.hd.value_counts().plot(kind="pie")

# %%
plt.hist(comp["screen"],facecolor="red",edgecolor="blue",bins=5)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
comp.screen.value_counts().plot(kind="pie")

# %%
plt.boxplot(comp["screen"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
plt.hist(comp["cd"],facecolor="red",edgecolor="blue",bins=2)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
plt.boxplot(comp["hd"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
comp.cd.value_counts().plot(kind="pie")

# %%
plt.hist(comp["multi"],facecolor="red",edgecolor="blue",bins=5)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
comp.multi.value_counts().plot(kind="pie")

# %%
plt.hist(comp["ads"],facecolor="red",edgecolor="blue",bins=5)
plt.title("Histogram",size=20,y=1.02)
# Out:
# Text(0.5, 1.02, 'Histogram')

# %%
plt.boxplot(comp["ads"])
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
comp.ads.value_counts().plot(kind="pie")
